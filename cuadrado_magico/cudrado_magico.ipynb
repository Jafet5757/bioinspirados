# %%
import random
from itertools import permutations
#Cudrados mágicos usando algoritmos genéticos

#n es el tamaño del cuadrado
def inicializar_poblacion(n, tam_poblacion):
    poblacion = []
    for i in range(tam_poblacion):
      cuadrado = []#representamos al cuadrado en una linea [1,2,3,4,5,6,7,8,9]
      #generamos n*n numeros aleatorios no repetidos
      cuadrado = random.sample(range(1, n*n+1), n*n)
      poblacion.append(cuadrado)
    return poblacion

#función fitness, recibe el cuadro y la constante magica (cm)
def evaluar_aptitud(poblacion, n, cm):
  for i in range(len(poblacion)):
    cuadrado = poblacion[i]
    #calculamos la suma de las filas
    suma_filas = 0
    for j in range(n):
      suma = 0
      for k in range(n):
        suma += cuadrado[j*n+k]
      suma_filas += abs(suma-cm)
    #calculamos la suma de las columnas
    suma_columnas = 0
    for j in range(n):
      suma = 0
      for k in range(n):
        suma += cuadrado[k*n+j]
      suma_columnas += abs(suma-cm)
    #calculamos la suma de las diagonales
    suma_diagonal1 = 0
    suma_diagonal2 = 0
    for j in range(n):
      suma_diagonal1 += cuadrado[j*n+j]
      suma_diagonal2 += cuadrado[j*n+(n-1-j)]
    suma_diagonal1 = abs(suma_diagonal1-cm)
    suma_diagonal2 = abs(suma_diagonal2-cm)
    #agregamos el aptitud a la poblacion
    aptitud = suma_filas + suma_columnas + suma_diagonal1 + suma_diagonal2
    poblacion[i] = [cuadrado, aptitud]
  return poblacion

# sleccion por torneo probabilistico
def defineParejas(tamPop, padres):
  #ordenamos padres de forma aleatoria
  parejas1 = random.sample(padres, len(padres))
  #generamos a la segunda pareja
  parejas2 = random.sample(padres, len(padres))
  #eliminamos al menos apto de las parejas
  parejas1 = torneoProbabilistico(tamPop, parejas1)
  parejas2 = torneoProbabilistico(tamPop, parejas2)
  #ahora generamos los padres, que son los indices de los padres
  indices = []
  for i in range(0, len(parejas1)):
    indices.append(padres.index(parejas1[i]))
    indices.append(padres.index(parejas2[i]))
  return indices


def torneoProbabilistico(tamTorneo, parejas):
  pseleccion = 0.8 #probabilidad de seleccion
  indices_eliminar = []
  for i in range(0, tamTorneo, 2):
    #generamos un numero aleatorio entre 0 y 1 que es la probabilidad de seleccion
    seleccion = random.uniform(0,1)
    if i+1 >= len(parejas):
      break
    elif seleccion <= pseleccion:
      #selecciona el mejor individuo
      if parejas[i][1] > parejas[i+1][1]:
        #elimina al individuo de menor aptitud
        indices_eliminar.append(i+1)
      else:
        indices_eliminar.append(i)
    else:
      #selecciona el peor individuo
      if parejas[i][1] < parejas[i+1][1]:
        #elimina al individuo de menor aptitud
        indices_eliminar.append(i+1)
      else:
        indices_eliminar.append(i)
  #eliminamos los individuos marcados
  indices_eliminar.sort(reverse=True)
  for i in indices_eliminar:
    parejas.pop(i)
  return parejas


#funcion de cruce
def orderBasedCrossover(padres, n, tam_poblacion):
  #generamos los indices de los padres
  indices = defineParejas(tam_poblacion, padres)
  #generamos los hijos
  hijos = []
  for i in range(0, len(indices), 2):
    #Obtenemos n*n/2 numeros aleatorios no repetidos
    puntos1 = random.sample(range(0, (n*n)-1), int(n*n/2))
    puntos2 = random.sample(range(0, (n*n)-1), int(n*n/2))
    #generamos los hijos que son las cadenas de los padres menos los puntos
    # Hacer copias de las cadenas de los padres
    padre1 = padres[indices[i]][0]
    padre2 = padres[indices[i+1]][0]

    hijo1 = list(padre1)
    hijo2 = list(padre2)
    #iteramos sobre los hijos y remplanzamos los puntos por -1
    for j in range(n*n):
      if hijo1[j] in puntos1:
        hijo1[j] = -1
      if hijo2[j] in puntos2:
        hijo2[j] = -1
    #ahora reemplazamos los -1 por los valores del otro padre
    for j in range(n*n):
      if hijo1[j] == -1:
        hijo1[j] = reemplazarValor(hijo1, padres[indices[i+1]][0])
      if hijo2[j] == -1:
        hijo2[j] = reemplazarValor(hijo2, padres[indices[i]][0])
    #agregamos los hijos a la lista de hijos
    hijos.append(hijo1)
    hijos.append(hijo2)
    
  return hijos

#funcion alternativa de mutacion heuristica
def mutacionHeuristica(cuadro,n,cm):
  #generamos n*n/2 numeros aleatorios no repetidos
  puntos = random.sample(range(0, len(cuadro)-1), int(len(cuadro)/2))
  #obtenemos todas las posibles permutaciones
  permutaciones = list(permutations(puntos))
  #generamos los nuevos cuadrados por cada permutacion
  cuadrados = []
  for i in range(len(permutaciones)):
    nuevoCuadrado = list(cuadro)
    for j in range(len(permutaciones[i])):
      nuevoCuadrado[puntos[j]] = cuadro[permutaciones[i][j]]
    cuadrados.append(nuevoCuadrado)
  #calculamos la aptitud de cada cuadrado
  aptitudes = evaluar_aptitud(cuadrados, n, cm)
  #ordenamos los cuadrados de menor a mayor aptitud
  aptitudes.sort(key=lambda x: x[1])
  #retornamos el mejor cuadrado
  return aptitudes[0][0]

#funcion para reemplazar los -1 por los valores del otro padre
def reemplazarValor(hijo, padre):
  for i in range(len(padre)):
    if padre[i] not in hijo:
      return padre[i]
    
#funcion de mutacion
def mutacionIntercambioReciproco(cuadro):
  #generamos dos numeros aleatorios no repetidos
  puntos = random.sample(range(0, len(cuadro)-1), 2)
  #intercambiamos los valores
  aux = cuadro[puntos[0]]
  cuadro[puntos[0]] = cuadro[puntos[1]]
  cuadro[puntos[1]] = aux
  return cuadro

#itera sobre la poblacion y aplica la mutacion si cumple con la probabilidad
def mutaciones(poblacion, coeficienteDeMutacion, n, cm):
  for i in range(len(poblacion)):
    #generamos un numero aleatorio entre 0 y 1 que es la probabilidad de mutacion
    mutacion = random.uniform(0,1)
    if mutacion <= coeficienteDeMutacion:
      poblacion[i][0] = mutacionIntercambioReciproco(poblacion[i][0])
      #calculamos la aptitud del individuo mutado
      poblacion[i][1] = evaluar_aptitud([poblacion[i][0]], n, cm)[0][1]
  return poblacion

def algoritmoGenetico(n, coeficienteDeMutacion, generaciones, tam_poblacion):
  #inicializamos la poblacion
  poblacion = inicializar_poblacion(n, tam_poblacion)
  #calculamos la constante magica
  cm = int((n*(n*n+1))/2)
  #evaluamos la aptitud de la poblacion
  poblacion = evaluar_aptitud(poblacion, n, cm)
  #iteramos por el numero de generaciones
  for i in range(generaciones):
    #seleccionamos los padres
    padres = poblacion
    #generamos los hijos
    hijos = orderBasedCrossover(padres, n, len(poblacion))
    #evaluamos la aptitud de los hijos
    hijos = evaluar_aptitud(hijos, n, cm)
    #unimos los hijos con los padres
    poblacion = padres + hijos
    #ordenamos la poblacion de menor a mayor aptitud
    poblacion.sort(key=lambda x: x[1])
    #aplicamos las mutaciones
    poblacion = mutaciones(poblacion, coeficienteDeMutacion, n, cm)
    #ordenamos la poblacion de menor a mayor aptitud
    poblacion.sort(key=lambda x: x[1])
    #eliminamos los individuos menos aptos
    poblacion = poblacion[:tam_poblacion]
    #imprimimos la mejor aptitud
    print("Generacion: ", i+1, " Mejor aptitud: ", poblacion[0][1])
    #si la aptitud es 0, terminamos el algoritmo
    if poblacion[0][1] == 0:
      break
  #imprimimos el mejor cuadrado
  print("Mejor cuadrado: ", poblacion[0][0])

algoritmoGenetico(5, 0.0625, 5000, 300)
# Out:
# Generacion:  1  Mejor aptitud:  69
# Generacion:  2  Mejor aptitud:  62
# Generacion:  3  Mejor aptitud:  59
# Generacion:  4  Mejor aptitud:  54
# Generacion:  5  Mejor aptitud:  54
# Generacion:  6  Mejor aptitud:  54
# Generacion:  7  Mejor aptitud:  54
# Generacion:  8  Mejor aptitud:  54
# Generacion:  9  Mejor aptitud:  54
# Generacion:  10  Mejor aptitud:  54
# Generacion:  11  Mejor aptitud:  54
# Generacion:  12  Mejor aptitud:  34
# Generacion:  13  Mejor aptitud:  34
# Generacion:  14  Mejor aptitud:  34
# Generacion:  15  Mejor aptitud:  34
# Generacion:  16  Mejor aptitud:  34
# Generacion:  17  Mejor aptitud:  34
# Generacion:  18  Mejor aptitud:  34
# Generacion:  19  Mejor aptitud:  34
# Generacion:  20  Mejor aptitud:  34
# Generacion:  21  Mejor aptitud:  44
# Generacion:  22  Mejor aptitud:  44
# Generacion:  23  Mejor aptitud:  44
# Generacion:  24  Mejor aptitud:  44
# Generacion:  25  Mejor aptitud:  44
# Generacion:  26  Mejor aptitud:  44
# Generacion:  27  Mejor aptitud:  43
# Generacion:  28  Mejor aptitud:  43
# Generacion:  29  Mejor aptitud:  43
# Generacion:  30  Mejor aptitud:  43
# Generacion:  31  Mejor aptitud:  43
# Generacion:  32  Mejor aptitud:  43
# Generacion:  33  Mejor aptitud:  43
# Generacion:  34  Mejor aptitud:  43
# Generacion:  35  Mejor aptitud:  29
# Generacion:  36  Mejor aptitud:  43
# Generacion:  37  Mejor aptitud:  43
# Generacion:  38  Mejor aptitud:  43
# Generacion:  39  Mejor aptitud:  43
# Generacion:  40  Mejor aptitud:  43
# Generacion:  41  Mejor aptitud:  43
# Generacion:  42  Mejor aptitud:  43
# Generacion:  43  Mejor aptitud:  43
# Generacion:  44  Mejor aptitud:  43
# Generacion:  45  Mejor aptitud:  43
# Generacion:  46  Mejor aptitud:  44
# Generacion:  47  Mejor aptitud:  45
# Generacion:  48  Mejor aptitud:  45
# Generacion:  49  Mejor aptitud:  45
# Generacion:  50  Mejor aptitud:  45
# Generacion:  51  Mejor aptitud:  45
# Generacion:  52  Mejor aptitud:  45
# Generacion:  53  Mejor aptitud:  45
# Generacion:  54  Mejor aptitud:  45
# Generacion:  55  Mejor aptitud:  42
# Generacion:  56  Mejor aptitud:  42
# Generacion:  57  Mejor aptitud:  42
# Generacion:  58  Mejor aptitud:  41
# Generacion:  59  Mejor aptitud:  39
# Generacion:  60  Mejor aptitud:  39
# Generacion:  61  Mejor aptitud:  39
# Generacion:  62  Mejor aptitud:  39
# Generacion:  63  Mejor aptitud:  32
# Generacion:  64  Mejor aptitud:  32
# Generacion:  65  Mejor aptitud:  32
# Generacion:  66  Mejor aptitud:  32
# Generacion:  67  Mejor aptitud:  32
# Generacion:  68  Mejor aptitud:  32
# Generacion:  69  Mejor aptitud:  32
# Generacion:  70  Mejor aptitud:  32
# Generacion:  71  Mejor aptitud:  32
# Generacion:  72  Mejor aptitud:  32
# Generacion:  73  Mejor aptitud:  32
# Generacion:  74  Mejor aptitud:  32
# Generacion:  75  Mejor aptitud:  32
# Generacion:  76  Mejor aptitud:  32
# Generacion:  77  Mejor aptitud:  32
# Generacion:  78  Mejor aptitud:  32
# Generacion:  79  Mejor aptitud:  32
# Generacion:  80  Mejor aptitud:  32
# Generacion:  81  Mejor aptitud:  32
# Generacion:  82  Mejor aptitud:  32
# Generacion:  83  Mejor aptitud:  38
# Generacion:  84  Mejor aptitud:  38
# Generacion:  85  Mejor aptitud:  37
# Generacion:  86  Mejor aptitud:  37
# Generacion:  87  Mejor aptitud:  37
# Generacion:  88  Mejor aptitud:  37
# Generacion:  89  Mejor aptitud:  37
# Generacion:  90  Mejor aptitud:  37
# Generacion:  91  Mejor aptitud:  37
# Generacion:  92  Mejor aptitud:  37
# Generacion:  93  Mejor aptitud:  37
# Generacion:  94  Mejor aptitud:  37
# Generacion:  95  Mejor aptitud:  37
# Generacion:  96  Mejor aptitud:  37
# Generacion:  97  Mejor aptitud:  37
# Generacion:  98  Mejor aptitud:  36
# Generacion:  99  Mejor aptitud:  36
# Generacion:  100  Mejor aptitud:  36
# Generacion:  101  Mejor aptitud:  36
# Generacion:  102  Mejor aptitud:  36
# Generacion:  103  Mejor aptitud:  29
# Generacion:  104  Mejor aptitud:  29
# Generacion:  105  Mejor aptitud:  29
# Generacion:  106  Mejor aptitud:  29
# Generacion:  107  Mejor aptitud:  29
# Generacion:  108  Mejor aptitud:  29
# Generacion:  109  Mejor aptitud:  29
# Generacion:  110  Mejor aptitud:  29
# Generacion:  111  Mejor aptitud:  29
# Generacion:  112  Mejor aptitud:  29
# Generacion:  113  Mejor aptitud:  29
# Generacion:  114  Mejor aptitud:  29
# Generacion:  115  Mejor aptitud:  29
# Generacion:  116  Mejor aptitud:  29
# Generacion:  117  Mejor aptitud:  29
# Generacion:  118  Mejor aptitud:  29
# Generacion:  119  Mejor aptitud:  29
# Generacion:  120  Mejor aptitud:  29
# Generacion:  121  Mejor aptitud:  29
# Generacion:  122  Mejor aptitud:  29
# Generacion:  123  Mejor aptitud:  29
# Generacion:  124  Mejor aptitud:  29
# Generacion:  125  Mejor aptitud:  29
# Generacion:  126  Mejor aptitud:  29
# Generacion:  127  Mejor aptitud:  29
# Generacion:  128  Mejor aptitud:  29
# Generacion:  129  Mejor aptitud:  29
# Generacion:  130  Mejor aptitud:  31
# Generacion:  131  Mejor aptitud:  31
# Generacion:  132  Mejor aptitud:  31
# Generacion:  133  Mejor aptitud:  31
# Generacion:  134  Mejor aptitud:  31
# Generacion:  135  Mejor aptitud:  31
# Generacion:  136  Mejor aptitud:  34
# Generacion:  137  Mejor aptitud:  34
# Generacion:  138  Mejor aptitud:  34
# Generacion:  139  Mejor aptitud:  34
# Generacion:  140  Mejor aptitud:  34
# Generacion:  141  Mejor aptitud:  32
# Generacion:  142  Mejor aptitud:  32
# Generacion:  143  Mejor aptitud:  32
# Generacion:  144  Mejor aptitud:  32
# Generacion:  145  Mejor aptitud:  35
# Generacion:  146  Mejor aptitud:  35
# Generacion:  147  Mejor aptitud:  35
# Generacion:  148  Mejor aptitud:  35
# Generacion:  149  Mejor aptitud:  35
# Generacion:  150  Mejor aptitud:  35
# Generacion:  151  Mejor aptitud:  35
# Generacion:  152  Mejor aptitud:  35
# Generacion:  153  Mejor aptitud:  32
# Generacion:  154  Mejor aptitud:  32
# Generacion:  155  Mejor aptitud:  36
# Generacion:  156  Mejor aptitud:  36
# Generacion:  157  Mejor aptitud:  35
# Generacion:  158  Mejor aptitud:  35
# Generacion:  159  Mejor aptitud:  35
# Generacion:  160  Mejor aptitud:  35
# Generacion:  161  Mejor aptitud:  35
# Generacion:  162  Mejor aptitud:  35
# Generacion:  163  Mejor aptitud:  35
# Generacion:  164  Mejor aptitud:  35
# Generacion:  165  Mejor aptitud:  35
# Generacion:  166  Mejor aptitud:  36
# Generacion:  167  Mejor aptitud:  36
# Generacion:  168  Mejor aptitud:  36
# Generacion:  169  Mejor aptitud:  36
# Generacion:  170  Mejor aptitud:  36
# Generacion:  171  Mejor aptitud:  36
# Generacion:  172  Mejor aptitud:  37
# Generacion:  173  Mejor aptitud:  37
# Generacion:  174  Mejor aptitud:  37
# Generacion:  175  Mejor aptitud:  31
# Generacion:  176  Mejor aptitud:  31
# Generacion:  177  Mejor aptitud:  29
# Generacion:  178  Mejor aptitud:  29
# Generacion:  179  Mejor aptitud:  29
# Generacion:  180  Mejor aptitud:  29
# Generacion:  181  Mejor aptitud:  29
# Generacion:  182  Mejor aptitud:  29
# Generacion:  183  Mejor aptitud:  29
# Generacion:  184  Mejor aptitud:  29
# Generacion:  185  Mejor aptitud:  29
# Generacion:  186  Mejor aptitud:  29
# Generacion:  187  Mejor aptitud:  29
# Generacion:  188  Mejor aptitud:  29
# Generacion:  189  Mejor aptitud:  29
# Generacion:  190  Mejor aptitud:  29
# Generacion:  191  Mejor aptitud:  29
# Generacion:  192  Mejor aptitud:  29
# Generacion:  193  Mejor aptitud:  29
# Generacion:  194  Mejor aptitud:  29
# Generacion:  195  Mejor aptitud:  29
# Generacion:  196  Mejor aptitud:  29
# Generacion:  197  Mejor aptitud:  29
# Generacion:  198  Mejor aptitud:  29
# Generacion:  199  Mejor aptitud:  29
# Generacion:  200  Mejor aptitud:  29
# Generacion:  201  Mejor aptitud:  29
# Generacion:  202  Mejor aptitud:  29
# Generacion:  203  Mejor aptitud:  29
# Generacion:  204  Mejor aptitud:  29
# Generacion:  205  Mejor aptitud:  29
# Generacion:  206  Mejor aptitud:  29
# Generacion:  207  Mejor aptitud:  29
# Generacion:  208  Mejor aptitud:  29
# Generacion:  209  Mejor aptitud:  29
# Generacion:  210  Mejor aptitud:  29
# Generacion:  211  Mejor aptitud:  29
# Generacion:  212  Mejor aptitud:  29
# Generacion:  213  Mejor aptitud:  29
# Generacion:  214  Mejor aptitud:  29
# Generacion:  215  Mejor aptitud:  29
# Generacion:  216  Mejor aptitud:  29
# Generacion:  217  Mejor aptitud:  29
# Generacion:  218  Mejor aptitud:  29
# Generacion:  219  Mejor aptitud:  29
# Generacion:  220  Mejor aptitud:  29
# Generacion:  221  Mejor aptitud:  29
# Generacion:  222  Mejor aptitud:  29
# Generacion:  223  Mejor aptitud:  29
# Generacion:  224  Mejor aptitud:  29
# Generacion:  225  Mejor aptitud:  29
# Generacion:  226  Mejor aptitud:  30
# Generacion:  227  Mejor aptitud:  30
# Generacion:  228  Mejor aptitud:  30
# Generacion:  229  Mejor aptitud:  30
# Generacion:  230  Mejor aptitud:  30
# Generacion:  231  Mejor aptitud:  30
# Generacion:  232  Mejor aptitud:  32
# Generacion:  233  Mejor aptitud:  32
# Generacion:  234  Mejor aptitud:  32
# Generacion:  235  Mejor aptitud:  32
# Generacion:  236  Mejor aptitud:  32
# Generacion:  237  Mejor aptitud:  32
# Generacion:  238  Mejor aptitud:  32
# Generacion:  239  Mejor aptitud:  32
# Generacion:  240  Mejor aptitud:  32
# Generacion:  241  Mejor aptitud:  32
# Generacion:  242  Mejor aptitud:  32
# Generacion:  243  Mejor aptitud:  32
# Generacion:  244  Mejor aptitud:  32
# Generacion:  245  Mejor aptitud:  32
# Generacion:  246  Mejor aptitud:  32
# Generacion:  247  Mejor aptitud:  32
# Generacion:  248  Mejor aptitud:  32
# Generacion:  249  Mejor aptitud:  32
# Generacion:  250  Mejor aptitud:  32
# Generacion:  251  Mejor aptitud:  32
# Generacion:  252  Mejor aptitud:  32
# Generacion:  253  Mejor aptitud:  32
# Generacion:  254  Mejor aptitud:  32
# Generacion:  255  Mejor aptitud:  32
# Generacion:  256  Mejor aptitud:  32
# Generacion:  257  Mejor aptitud:  32
# Generacion:  258  Mejor aptitud:  32
# Generacion:  259  Mejor aptitud:  31
# Generacion:  260  Mejor aptitud:  32
# Generacion:  261  Mejor aptitud:  32
# Generacion:  262  Mejor aptitud:  32
# Generacion:  263  Mejor aptitud:  32
# Generacion:  264  Mejor aptitud:  32
# Generacion:  265  Mejor aptitud:  32
# Generacion:  266  Mejor aptitud:  32
# Generacion:  267  Mejor aptitud:  32
# Generacion:  268  Mejor aptitud:  32
# Generacion:  269  Mejor aptitud:  32
# Generacion:  270  Mejor aptitud:  32
# Generacion:  271  Mejor aptitud:  32
# Generacion:  272  Mejor aptitud:  32
# Generacion:  273  Mejor aptitud:  32
# Generacion:  274  Mejor aptitud:  32
# Generacion:  275  Mejor aptitud:  32
# Generacion:  276  Mejor aptitud:  32
# Generacion:  277  Mejor aptitud:  32
# Generacion:  278  Mejor aptitud:  32
# Generacion:  279  Mejor aptitud:  32
# Generacion:  280  Mejor aptitud:  32
# Generacion:  281  Mejor aptitud:  32
# Generacion:  282  Mejor aptitud:  32
# Generacion:  283  Mejor aptitud:  32
# Generacion:  284  Mejor aptitud:  32
# Generacion:  285  Mejor aptitud:  32
# Generacion:  286  Mejor aptitud:  32
# Generacion:  287  Mejor aptitud:  32
# Generacion:  288  Mejor aptitud:  32
# Generacion:  289  Mejor aptitud:  32
# Generacion:  290  Mejor aptitud:  32
# Generacion:  291  Mejor aptitud:  32
# Generacion:  292  Mejor aptitud:  32
# Generacion:  293  Mejor aptitud:  32
# Generacion:  294  Mejor aptitud:  32
# Generacion:  295  Mejor aptitud:  32
# Generacion:  296  Mejor aptitud:  32
# Generacion:  297  Mejor aptitud:  32
# Generacion:  298  Mejor aptitud:  32
# Generacion:  299  Mejor aptitud:  32
# Generacion:  300  Mejor aptitud:  32
# Generacion:  301  Mejor aptitud:  31
# Generacion:  302  Mejor aptitud:  31
# Generacion:  303  Mejor aptitud:  31
# Generacion:  304  Mejor aptitud:  31
# Generacion:  305  Mejor aptitud:  31
# Generacion:  306  Mejor aptitud:  31
# Generacion:  307  Mejor aptitud:  31
# Generacion:  308  Mejor aptitud:  31
# Generacion:  309  Mejor aptitud:  31
# Generacion:  310  Mejor aptitud:  28
# Generacion:  311  Mejor aptitud:  28
# Generacion:  312  Mejor aptitud:  31
# Generacion:  313  Mejor aptitud:  31
# Generacion:  314  Mejor aptitud:  31
# Generacion:  315  Mejor aptitud:  31
# Generacion:  316  Mejor aptitud:  32
# Generacion:  317  Mejor aptitud:  32
# Generacion:  318  Mejor aptitud:  32
# Generacion:  319  Mejor aptitud:  27
# Generacion:  320  Mejor aptitud:  27
# Generacion:  321  Mejor aptitud:  27
# Generacion:  322  Mejor aptitud:  27
# Generacion:  323  Mejor aptitud:  27
# Generacion:  324  Mejor aptitud:  27
# Generacion:  325  Mejor aptitud:  27
# Generacion:  326  Mejor aptitud:  27
# Generacion:  327  Mejor aptitud:  27
# Generacion:  328  Mejor aptitud:  27
# Generacion:  329  Mejor aptitud:  27
# Generacion:  330  Mejor aptitud:  27
# Generacion:  331  Mejor aptitud:  27
# Generacion:  332  Mejor aptitud:  27
# Generacion:  333  Mejor aptitud:  27
# Generacion:  334  Mejor aptitud:  27
# Generacion:  335  Mejor aptitud:  27
# Generacion:  336  Mejor aptitud:  27
# Generacion:  337  Mejor aptitud:  27
# Generacion:  338  Mejor aptitud:  27
# Generacion:  339  Mejor aptitud:  27
# Generacion:  340  Mejor aptitud:  27
# Generacion:  341  Mejor aptitud:  27
# Generacion:  342  Mejor aptitud:  27
# Generacion:  343  Mejor aptitud:  27
# Generacion:  344  Mejor aptitud:  27
# Generacion:  345  Mejor aptitud:  27
# Generacion:  346  Mejor aptitud:  27
# Generacion:  347  Mejor aptitud:  27
# Generacion:  348  Mejor aptitud:  27
# Generacion:  349  Mejor aptitud:  27
# Generacion:  350  Mejor aptitud:  27
# Generacion:  351  Mejor aptitud:  27
# Generacion:  352  Mejor aptitud:  27
# Generacion:  353  Mejor aptitud:  27
# Generacion:  354  Mejor aptitud:  27
# Generacion:  355  Mejor aptitud:  37
# Generacion:  356  Mejor aptitud:  37
# Generacion:  357  Mejor aptitud:  37
# Generacion:  358  Mejor aptitud:  36
# Generacion:  359  Mejor aptitud:  34
# Generacion:  360  Mejor aptitud:  34
# Generacion:  361  Mejor aptitud:  34
# Generacion:  362  Mejor aptitud:  34
# Generacion:  363  Mejor aptitud:  34
# Generacion:  364  Mejor aptitud:  34
# Generacion:  365  Mejor aptitud:  34
# Generacion:  366  Mejor aptitud:  34
# Generacion:  367  Mejor aptitud:  34
# Generacion:  368  Mejor aptitud:  34
# Generacion:  369  Mejor aptitud:  34
# Generacion:  370  Mejor aptitud:  34
# Generacion:  371  Mejor aptitud:  34
# Generacion:  372  Mejor aptitud:  34
# Generacion:  373  Mejor aptitud:  34
# Generacion:  374  Mejor aptitud:  41
# Generacion:  375  Mejor aptitud:  41
# Generacion:  376  Mejor aptitud:  41
# Generacion:  377  Mejor aptitud:  41
# Generacion:  378  Mejor aptitud:  41
# Generacion:  379  Mejor aptitud:  41
# Generacion:  380  Mejor aptitud:  30
# Generacion:  381  Mejor aptitud:  30
# Generacion:  382  Mejor aptitud:  30
# Generacion:  383  Mejor aptitud:  30
# Generacion:  384  Mejor aptitud:  30
# Generacion:  385  Mejor aptitud:  30
# Generacion:  386  Mejor aptitud:  30
# Generacion:  387  Mejor aptitud:  30
# Generacion:  388  Mejor aptitud:  30
# Generacion:  389  Mejor aptitud:  30
# Generacion:  390  Mejor aptitud:  30
# Generacion:  391  Mejor aptitud:  30
# Generacion:  392  Mejor aptitud:  30
# Generacion:  393  Mejor aptitud:  30
# Generacion:  394  Mejor aptitud:  30
# Generacion:  395  Mejor aptitud:  30
# Generacion:  396  Mejor aptitud:  30
# Generacion:  397  Mejor aptitud:  30
# Generacion:  398  Mejor aptitud:  30
# Generacion:  399  Mejor aptitud:  30
# Generacion:  400  Mejor aptitud:  30
# Generacion:  401  Mejor aptitud:  30
# Generacion:  402  Mejor aptitud:  31
# Generacion:  403  Mejor aptitud:  32
# Generacion:  404  Mejor aptitud:  32
# Generacion:  405  Mejor aptitud:  32
# Generacion:  406  Mejor aptitud:  32
# Generacion:  407  Mejor aptitud:  32
# Generacion:  408  Mejor aptitud:  32
# Generacion:  409  Mejor aptitud:  32
# Generacion:  410  Mejor aptitud:  32
# Generacion:  411  Mejor aptitud:  32
# Generacion:  412  Mejor aptitud:  32
# Generacion:  413  Mejor aptitud:  32
# Generacion:  414  Mejor aptitud:  32
# Generacion:  415  Mejor aptitud:  32
# Generacion:  416  Mejor aptitud:  32
# Generacion:  417  Mejor aptitud:  32
# Generacion:  418  Mejor aptitud:  32
# Generacion:  419  Mejor aptitud:  34
# Generacion:  420  Mejor aptitud:  34
# Generacion:  421  Mejor aptitud:  34
# Generacion:  422  Mejor aptitud:  34
# Generacion:  423  Mejor aptitud:  34
# Generacion:  424  Mejor aptitud:  34
# Generacion:  425  Mejor aptitud:  34
# Generacion:  426  Mejor aptitud:  30
# Generacion:  427  Mejor aptitud:  35
# Generacion:  428  Mejor aptitud:  35
# Generacion:  429  Mejor aptitud:  35
# Generacion:  430  Mejor aptitud:  35
# Generacion:  431  Mejor aptitud:  35
# Generacion:  432  Mejor aptitud:  35
# Generacion:  433  Mejor aptitud:  35
# Generacion:  434  Mejor aptitud:  34
# Generacion:  435  Mejor aptitud:  34
# Generacion:  436  Mejor aptitud:  34
# Generacion:  437  Mejor aptitud:  34
# Generacion:  438  Mejor aptitud:  34
# Generacion:  439  Mejor aptitud:  29
# Generacion:  440  Mejor aptitud:  29
# Generacion:  441  Mejor aptitud:  29
# Generacion:  442  Mejor aptitud:  29
# Generacion:  443  Mejor aptitud:  29
# Generacion:  444  Mejor aptitud:  29
# Generacion:  445  Mejor aptitud:  29
# Generacion:  446  Mejor aptitud:  29
# Generacion:  447  Mejor aptitud:  29
# Generacion:  448  Mejor aptitud:  29
# Generacion:  449  Mejor aptitud:  29
# Generacion:  450  Mejor aptitud:  29
# Generacion:  451  Mejor aptitud:  29
# Generacion:  452  Mejor aptitud:  29
# Generacion:  453  Mejor aptitud:  29
# Generacion:  454  Mejor aptitud:  29
# Generacion:  455  Mejor aptitud:  29
# Generacion:  456  Mejor aptitud:  29
# Generacion:  457  Mejor aptitud:  29
# Generacion:  458  Mejor aptitud:  29
# Generacion:  459  Mejor aptitud:  29
# Generacion:  460  Mejor aptitud:  29
# Generacion:  461  Mejor aptitud:  29
# Generacion:  462  Mejor aptitud:  36
# Generacion:  463  Mejor aptitud:  36
# Generacion:  464  Mejor aptitud:  36
# Generacion:  465  Mejor aptitud:  36
# Generacion:  466  Mejor aptitud:  36
# Generacion:  467  Mejor aptitud:  35
# Generacion:  468  Mejor aptitud:  35
# Generacion:  469  Mejor aptitud:  35
# Generacion:  470  Mejor aptitud:  35
# Generacion:  471  Mejor aptitud:  35
# Generacion:  472  Mejor aptitud:  35
# Generacion:  473  Mejor aptitud:  35
# Generacion:  474  Mejor aptitud:  35
# Generacion:  475  Mejor aptitud:  35
# Generacion:  476  Mejor aptitud:  35
# Generacion:  477  Mejor aptitud:  35
# Generacion:  478  Mejor aptitud:  35
# Generacion:  479  Mejor aptitud:  35
# Generacion:  480  Mejor aptitud:  31
# Generacion:  481  Mejor aptitud:  31
# Generacion:  482  Mejor aptitud:  31
# Generacion:  483  Mejor aptitud:  31
# Generacion:  484  Mejor aptitud:  31
# Generacion:  485  Mejor aptitud:  31
# Generacion:  486  Mejor aptitud:  31
# Generacion:  487  Mejor aptitud:  31
# Generacion:  488  Mejor aptitud:  31
# Generacion:  489  Mejor aptitud:  31
# Generacion:  490  Mejor aptitud:  31
# Generacion:  491  Mejor aptitud:  31
# Generacion:  492  Mejor aptitud:  31
# Generacion:  493  Mejor aptitud:  32
# Generacion:  494  Mejor aptitud:  32
# Generacion:  495  Mejor aptitud:  32
# Generacion:  496  Mejor aptitud:  32
# Generacion:  497  Mejor aptitud:  32
# Generacion:  498  Mejor aptitud:  32
# Generacion:  499  Mejor aptitud:  32
# Generacion:  500  Mejor aptitud:  31
# Generacion:  501  Mejor aptitud:  31
# Generacion:  502  Mejor aptitud:  31
# Generacion:  503  Mejor aptitud:  31
# Generacion:  504  Mejor aptitud:  31
# Generacion:  505  Mejor aptitud:  31
# Generacion:  506  Mejor aptitud:  31
# Generacion:  507  Mejor aptitud:  31
# Generacion:  508  Mejor aptitud:  31
# Generacion:  509  Mejor aptitud:  31
# Generacion:  510  Mejor aptitud:  31
# Generacion:  511  Mejor aptitud:  31
# Generacion:  512  Mejor aptitud:  31
# Generacion:  513  Mejor aptitud:  31
# Generacion:  514  Mejor aptitud:  32
# Generacion:  515  Mejor aptitud:  32
# Generacion:  516  Mejor aptitud:  32
# Generacion:  517  Mejor aptitud:  32
# Generacion:  518  Mejor aptitud:  27
# Generacion:  519  Mejor aptitud:  27
# Generacion:  520  Mejor aptitud:  27
# Generacion:  521  Mejor aptitud:  27
# Generacion:  522  Mejor aptitud:  27
# Generacion:  523  Mejor aptitud:  27
# Generacion:  524  Mejor aptitud:  27
# Generacion:  525  Mejor aptitud:  27
# Generacion:  526  Mejor aptitud:  27
# Generacion:  527  Mejor aptitud:  27
# Generacion:  528  Mejor aptitud:  27
# Generacion:  529  Mejor aptitud:  23
# Generacion:  530  Mejor aptitud:  23
# Generacion:  531  Mejor aptitud:  23
# Generacion:  532  Mejor aptitud:  23
# Generacion:  533  Mejor aptitud:  23
# Generacion:  534  Mejor aptitud:  23
# Generacion:  535  Mejor aptitud:  23
# Generacion:  536  Mejor aptitud:  23
# Generacion:  537  Mejor aptitud:  23
# Generacion:  538  Mejor aptitud:  23
# Generacion:  539  Mejor aptitud:  23
# Generacion:  540  Mejor aptitud:  23
# Generacion:  541  Mejor aptitud:  23
# Generacion:  542  Mejor aptitud:  23
# Generacion:  543  Mejor aptitud:  33
# Generacion:  544  Mejor aptitud:  33
# Generacion:  545  Mejor aptitud:  33
# Generacion:  546  Mejor aptitud:  33
# Generacion:  547  Mejor aptitud:  33
# Generacion:  548  Mejor aptitud:  34
# Generacion:  549  Mejor aptitud:  34
# Generacion:  550  Mejor aptitud:  34
# Generacion:  551  Mejor aptitud:  34
# Generacion:  552  Mejor aptitud:  34
# Generacion:  553  Mejor aptitud:  29
# Generacion:  554  Mejor aptitud:  29
# Generacion:  555  Mejor aptitud:  29
# Generacion:  556  Mejor aptitud:  29
# Generacion:  557  Mejor aptitud:  27
# Generacion:  558  Mejor aptitud:  27
# Generacion:  559  Mejor aptitud:  27
# Generacion:  560  Mejor aptitud:  27
# Generacion:  561  Mejor aptitud:  27
# Generacion:  562  Mejor aptitud:  27
# Generacion:  563  Mejor aptitud:  27
# Generacion:  564  Mejor aptitud:  27
# Generacion:  565  Mejor aptitud:  27
# Generacion:  566  Mejor aptitud:  27
# Generacion:  567  Mejor aptitud:  27
# Generacion:  568  Mejor aptitud:  27
# Generacion:  569  Mejor aptitud:  29
# Generacion:  570  Mejor aptitud:  29
# Generacion:  571  Mejor aptitud:  29
# Generacion:  572  Mejor aptitud:  29
# Generacion:  573  Mejor aptitud:  29
# Generacion:  574  Mejor aptitud:  29
# Generacion:  575  Mejor aptitud:  29
# Generacion:  576  Mejor aptitud:  33
# Generacion:  577  Mejor aptitud:  33
# Generacion:  578  Mejor aptitud:  33
# Generacion:  579  Mejor aptitud:  33
# Generacion:  580  Mejor aptitud:  33
# Generacion:  581  Mejor aptitud:  33
# Generacion:  582  Mejor aptitud:  33
# Generacion:  583  Mejor aptitud:  32
# Generacion:  584  Mejor aptitud:  32
# Generacion:  585  Mejor aptitud:  32
# Generacion:  586  Mejor aptitud:  32
# Generacion:  587  Mejor aptitud:  32
# Generacion:  588  Mejor aptitud:  32
# Generacion:  589  Mejor aptitud:  32
# Generacion:  590  Mejor aptitud:  33
# Generacion:  591  Mejor aptitud:  33
# Generacion:  592  Mejor aptitud:  33
# Generacion:  593  Mejor aptitud:  33
# Generacion:  594  Mejor aptitud:  33
# Generacion:  595  Mejor aptitud:  33
# Generacion:  596  Mejor aptitud:  33
# Generacion:  597  Mejor aptitud:  33
# Generacion:  598  Mejor aptitud:  33
# Generacion:  599  Mejor aptitud:  33
# Generacion:  600  Mejor aptitud:  33
# Generacion:  601  Mejor aptitud:  33
# Generacion:  602  Mejor aptitud:  33
# Generacion:  603  Mejor aptitud:  33
# Generacion:  604  Mejor aptitud:  33
# Generacion:  605  Mejor aptitud:  33
# Generacion:  606  Mejor aptitud:  33
# Generacion:  607  Mejor aptitud:  33
# Generacion:  608  Mejor aptitud:  33
# Generacion:  609  Mejor aptitud:  33
# Generacion:  610  Mejor aptitud:  33
# Generacion:  611  Mejor aptitud:  33
# Generacion:  612  Mejor aptitud:  33
# Generacion:  613  Mejor aptitud:  33
# Generacion:  614  Mejor aptitud:  33
# Generacion:  615  Mejor aptitud:  33
# Generacion:  616  Mejor aptitud:  30
# Generacion:  617  Mejor aptitud:  30
# Generacion:  618  Mejor aptitud:  30
# Generacion:  619  Mejor aptitud:  30
# Generacion:  620  Mejor aptitud:  30
# Generacion:  621  Mejor aptitud:  30
# Generacion:  622  Mejor aptitud:  30
# Generacion:  623  Mejor aptitud:  30
# Generacion:  624  Mejor aptitud:  30
# Generacion:  625  Mejor aptitud:  33
# Generacion:  626  Mejor aptitud:  33
# Generacion:  627  Mejor aptitud:  33
# Generacion:  628  Mejor aptitud:  33
# Generacion:  629  Mejor aptitud:  33
# Generacion:  630  Mejor aptitud:  30
# Generacion:  631  Mejor aptitud:  30
# Generacion:  632  Mejor aptitud:  30
# Generacion:  633  Mejor aptitud:  30
# Generacion:  634  Mejor aptitud:  30
# Generacion:  635  Mejor aptitud:  30
# Generacion:  636  Mejor aptitud:  33
# Generacion:  637  Mejor aptitud:  33
# Generacion:  638  Mejor aptitud:  33
# Generacion:  639  Mejor aptitud:  33
# Generacion:  640  Mejor aptitud:  34
# Generacion:  641  Mejor aptitud:  34
# Generacion:  642  Mejor aptitud:  35
# Generacion:  643  Mejor aptitud:  35
# Generacion:  644  Mejor aptitud:  35
# Generacion:  645  Mejor aptitud:  35
# Generacion:  646  Mejor aptitud:  35
# Generacion:  647  Mejor aptitud:  35
# Generacion:  648  Mejor aptitud:  35
# Generacion:  649  Mejor aptitud:  37
# Generacion:  650  Mejor aptitud:  31
# Generacion:  651  Mejor aptitud:  31
# Generacion:  652  Mejor aptitud:  31
# Generacion:  653  Mejor aptitud:  28
# Generacion:  654  Mejor aptitud:  28
# Generacion:  655  Mejor aptitud:  28
# Generacion:  656  Mejor aptitud:  28
# Generacion:  657  Mejor aptitud:  28
# Generacion:  658  Mejor aptitud:  28
# Generacion:  659  Mejor aptitud:  28
# Generacion:  660  Mejor aptitud:  28
# Generacion:  661  Mejor aptitud:  28
# Generacion:  662  Mejor aptitud:  28
# Generacion:  663  Mejor aptitud:  28
# Generacion:  664  Mejor aptitud:  28
# Generacion:  665  Mejor aptitud:  32
# Generacion:  666  Mejor aptitud:  32
# Generacion:  667  Mejor aptitud:  32
# Generacion:  668  Mejor aptitud:  36
# Generacion:  669  Mejor aptitud:  36
# Generacion:  670  Mejor aptitud:  36
# Generacion:  671  Mejor aptitud:  33
# Generacion:  672  Mejor aptitud:  33
# Generacion:  673  Mejor aptitud:  33
# Generacion:  674  Mejor aptitud:  33
# Generacion:  675  Mejor aptitud:  33
# Generacion:  676  Mejor aptitud:  27
# Generacion:  677  Mejor aptitud:  27
# Generacion:  678  Mejor aptitud:  27
# Generacion:  679  Mejor aptitud:  27
# Generacion:  680  Mejor aptitud:  27
# Generacion:  681  Mejor aptitud:  27
# Generacion:  682  Mejor aptitud:  27
# Generacion:  683  Mejor aptitud:  27
# Generacion:  684  Mejor aptitud:  27
# Generacion:  685  Mejor aptitud:  27
# Generacion:  686  Mejor aptitud:  27
# Generacion:  687  Mejor aptitud:  27
# Generacion:  688  Mejor aptitud:  27
# Generacion:  689  Mejor aptitud:  27
# Generacion:  690  Mejor aptitud:  27
# Generacion:  691  Mejor aptitud:  27
# Generacion:  692  Mejor aptitud:  27
# Generacion:  693  Mejor aptitud:  27
# Generacion:  694  Mejor aptitud:  27
# Generacion:  695  Mejor aptitud:  27
# Generacion:  696  Mejor aptitud:  27
# Generacion:  697  Mejor aptitud:  27
# Generacion:  698  Mejor aptitud:  27
# Generacion:  699  Mejor aptitud:  27
# Generacion:  700  Mejor aptitud:  27
# Generacion:  701  Mejor aptitud:  27
# Generacion:  702  Mejor aptitud:  27
# Generacion:  703  Mejor aptitud:  27
# Generacion:  704  Mejor aptitud:  27
# Generacion:  705  Mejor aptitud:  27
# Generacion:  706  Mejor aptitud:  27
# Generacion:  707  Mejor aptitud:  27
# Generacion:  708  Mejor aptitud:  27
# Generacion:  709  Mejor aptitud:  27
# Generacion:  710  Mejor aptitud:  27
# Generacion:  711  Mejor aptitud:  27
# Generacion:  712  Mejor aptitud:  27
# Generacion:  713  Mejor aptitud:  27
# Generacion:  714  Mejor aptitud:  27
# Generacion:  715  Mejor aptitud:  27
# Generacion:  716  Mejor aptitud:  27
# Generacion:  717  Mejor aptitud:  27
# Generacion:  718  Mejor aptitud:  27
# Generacion:  719  Mejor aptitud:  27
# Generacion:  720  Mejor aptitud:  27
# Generacion:  721  Mejor aptitud:  27
# Generacion:  722  Mejor aptitud:  27
# Generacion:  723  Mejor aptitud:  27
# Generacion:  724  Mejor aptitud:  27
# Generacion:  725  Mejor aptitud:  27
# Generacion:  726  Mejor aptitud:  27
# Generacion:  727  Mejor aptitud:  27
# Generacion:  728  Mejor aptitud:  27
# Generacion:  729  Mejor aptitud:  27
# Generacion:  730  Mejor aptitud:  38
# Generacion:  731  Mejor aptitud:  38
# Generacion:  732  Mejor aptitud:  38
# Generacion:  733  Mejor aptitud:  38
# Generacion:  734  Mejor aptitud:  34
# Generacion:  735  Mejor aptitud:  33
# Generacion:  736  Mejor aptitud:  33
# Generacion:  737  Mejor aptitud:  33
# Generacion:  738  Mejor aptitud:  33
# Generacion:  739  Mejor aptitud:  33
# Generacion:  740  Mejor aptitud:  33
# Generacion:  741  Mejor aptitud:  33
# Generacion:  742  Mejor aptitud:  33
# Generacion:  743  Mejor aptitud:  33
# Generacion:  744  Mejor aptitud:  33
# Generacion:  745  Mejor aptitud:  31
# Generacion:  746  Mejor aptitud:  31
# Generacion:  747  Mejor aptitud:  31
# Generacion:  748  Mejor aptitud:  31
# Generacion:  749  Mejor aptitud:  31
# Generacion:  750  Mejor aptitud:  31
# Generacion:  751  Mejor aptitud:  31
# Generacion:  752  Mejor aptitud:  31
# Generacion:  753  Mejor aptitud:  31
# Generacion:  754  Mejor aptitud:  38
# Generacion:  755  Mejor aptitud:  38
# Generacion:  756  Mejor aptitud:  38
# Generacion:  757  Mejor aptitud:  38
# Generacion:  758  Mejor aptitud:  38
# Generacion:  759  Mejor aptitud:  31
# Generacion:  760  Mejor aptitud:  31
# Generacion:  761  Mejor aptitud:  31
# Generacion:  762  Mejor aptitud:  31
# Generacion:  763  Mejor aptitud:  31
# Generacion:  764  Mejor aptitud:  31
# Generacion:  765  Mejor aptitud:  31
# Generacion:  766  Mejor aptitud:  31
# Generacion:  767  Mejor aptitud:  31
# Generacion:  768  Mejor aptitud:  31
# Generacion:  769  Mejor aptitud:  31
# Generacion:  770  Mejor aptitud:  31
# Generacion:  771  Mejor aptitud:  31
# Generacion:  772  Mejor aptitud:  31
# Generacion:  773  Mejor aptitud:  31
# Generacion:  774  Mejor aptitud:  31
# Generacion:  775  Mejor aptitud:  31
# Generacion:  776  Mejor aptitud:  28
# Generacion:  777  Mejor aptitud:  28
# Generacion:  778  Mejor aptitud:  28
# Generacion:  779  Mejor aptitud:  28
# Generacion:  780  Mejor aptitud:  28
# Generacion:  781  Mejor aptitud:  28
# Generacion:  782  Mejor aptitud:  28
# Generacion:  783  Mejor aptitud:  28
# Generacion:  784  Mejor aptitud:  28
# Generacion:  785  Mejor aptitud:  28
# Generacion:  786  Mejor aptitud:  28
# Generacion:  787  Mejor aptitud:  28
# Generacion:  788  Mejor aptitud:  28
# Generacion:  789  Mejor aptitud:  30
# Generacion:  790  Mejor aptitud:  30
# Generacion:  791  Mejor aptitud:  30
# Generacion:  792  Mejor aptitud:  30
# Generacion:  793  Mejor aptitud:  30
# Generacion:  794  Mejor aptitud:  30
# Generacion:  795  Mejor aptitud:  30
# Generacion:  796  Mejor aptitud:  29
# Generacion:  797  Mejor aptitud:  29
# Generacion:  798  Mejor aptitud:  29
# Generacion:  799  Mejor aptitud:  29
# Generacion:  800  Mejor aptitud:  29
# Generacion:  801  Mejor aptitud:  29
# Generacion:  802  Mejor aptitud:  29
# Generacion:  803  Mejor aptitud:  30
# Generacion:  804  Mejor aptitud:  30
# Generacion:  805  Mejor aptitud:  30
# Generacion:  806  Mejor aptitud:  30
# Generacion:  807  Mejor aptitud:  30
# Generacion:  808  Mejor aptitud:  30
# Generacion:  809  Mejor aptitud:  30
# Generacion:  810  Mejor aptitud:  30
# Generacion:  811  Mejor aptitud:  33
# Generacion:  812  Mejor aptitud:  33
# Generacion:  813  Mejor aptitud:  33
# Generacion:  814  Mejor aptitud:  33
# Generacion:  815  Mejor aptitud:  33
# Generacion:  816  Mejor aptitud:  33
# Generacion:  817  Mejor aptitud:  33
# Generacion:  818  Mejor aptitud:  33
# Generacion:  819  Mejor aptitud:  33
# Generacion:  820  Mejor aptitud:  33
# Generacion:  821  Mejor aptitud:  33
# Generacion:  822  Mejor aptitud:  33
# Generacion:  823  Mejor aptitud:  33
# Generacion:  824  Mejor aptitud:  33
# Generacion:  825  Mejor aptitud:  33
# Generacion:  826  Mejor aptitud:  33
# Generacion:  827  Mejor aptitud:  31
# Generacion:  828  Mejor aptitud:  31
# Generacion:  829  Mejor aptitud:  31
# Generacion:  830  Mejor aptitud:  31
# Generacion:  831  Mejor aptitud:  24
# Generacion:  832  Mejor aptitud:  24
# Generacion:  833  Mejor aptitud:  24
# Generacion:  834  Mejor aptitud:  24
# Generacion:  835  Mejor aptitud:  24
# Generacion:  836  Mejor aptitud:  24
# Generacion:  837  Mejor aptitud:  24
# Generacion:  838  Mejor aptitud:  24
# Generacion:  839  Mejor aptitud:  24
# Generacion:  840  Mejor aptitud:  24
# Generacion:  841  Mejor aptitud:  24
# Generacion:  842  Mejor aptitud:  24
# Generacion:  843  Mejor aptitud:  24
# Generacion:  844  Mejor aptitud:  24
# Generacion:  845  Mejor aptitud:  24
# Generacion:  846  Mejor aptitud:  24
# Generacion:  847  Mejor aptitud:  33
# Generacion:  848  Mejor aptitud:  33
# Generacion:  849  Mejor aptitud:  33
# Generacion:  850  Mejor aptitud:  33
# Generacion:  851  Mejor aptitud:  33
# Generacion:  852  Mejor aptitud:  33
# Generacion:  853  Mejor aptitud:  33
# Generacion:  854  Mejor aptitud:  33
# Generacion:  855  Mejor aptitud:  32
# Generacion:  856  Mejor aptitud:  32
# Generacion:  857  Mejor aptitud:  32
# Generacion:  858  Mejor aptitud:  32
# Generacion:  859  Mejor aptitud:  32
# Generacion:  860  Mejor aptitud:  32
# Generacion:  861  Mejor aptitud:  32
# Generacion:  862  Mejor aptitud:  32
# Generacion:  863  Mejor aptitud:  32
# Generacion:  864  Mejor aptitud:  29
# Generacion:  865  Mejor aptitud:  29
# Generacion:  866  Mejor aptitud:  29
# Generacion:  867  Mejor aptitud:  29
# Generacion:  868  Mejor aptitud:  29
# Generacion:  869  Mejor aptitud:  29
# Generacion:  870  Mejor aptitud:  32
# Generacion:  871  Mejor aptitud:  32
# Generacion:  872  Mejor aptitud:  32
# Generacion:  873  Mejor aptitud:  33
# Generacion:  874  Mejor aptitud:  33
# Generacion:  875  Mejor aptitud:  28
# Generacion:  876  Mejor aptitud:  28
# Generacion:  877  Mejor aptitud:  28
# Generacion:  878  Mejor aptitud:  23
# Generacion:  879  Mejor aptitud:  23
# Generacion:  880  Mejor aptitud:  23
# Generacion:  881  Mejor aptitud:  23
# Generacion:  882  Mejor aptitud:  23
# Generacion:  883  Mejor aptitud:  23
# Generacion:  884  Mejor aptitud:  23
# Generacion:  885  Mejor aptitud:  23
# Generacion:  886  Mejor aptitud:  23
# Generacion:  887  Mejor aptitud:  23
# Generacion:  888  Mejor aptitud:  23
# Generacion:  889  Mejor aptitud:  23
# Generacion:  890  Mejor aptitud:  23
# Generacion:  891  Mejor aptitud:  23
# Generacion:  892  Mejor aptitud:  23
# Generacion:  893  Mejor aptitud:  19
# Generacion:  894  Mejor aptitud:  19
# Generacion:  895  Mejor aptitud:  19
# Generacion:  896  Mejor aptitud:  19
# Generacion:  897  Mejor aptitud:  19
# Generacion:  898  Mejor aptitud:  19
# Generacion:  899  Mejor aptitud:  19
# Generacion:  900  Mejor aptitud:  23
# Generacion:  901  Mejor aptitud:  23
# Generacion:  902  Mejor aptitud:  23
# Generacion:  903  Mejor aptitud:  23
# Generacion:  904  Mejor aptitud:  23
# Generacion:  905  Mejor aptitud:  27
# Generacion:  906  Mejor aptitud:  27
# Generacion:  907  Mejor aptitud:  23
# Generacion:  908  Mejor aptitud:  23
# Generacion:  909  Mejor aptitud:  23
# Generacion:  910  Mejor aptitud:  23
# Generacion:  911  Mejor aptitud:  23
# Generacion:  912  Mejor aptitud:  23
# Generacion:  913  Mejor aptitud:  23
# Generacion:  914  Mejor aptitud:  23
# Generacion:  915  Mejor aptitud:  23
# Generacion:  916  Mejor aptitud:  23
# Generacion:  917  Mejor aptitud:  23
# Generacion:  918  Mejor aptitud:  23
# Generacion:  919  Mejor aptitud:  23
# Generacion:  920  Mejor aptitud:  23
# Generacion:  921  Mejor aptitud:  23
# Generacion:  922  Mejor aptitud:  23
# Generacion:  923  Mejor aptitud:  23
# Generacion:  924  Mejor aptitud:  23
# Generacion:  925  Mejor aptitud:  27
# Generacion:  926  Mejor aptitud:  27
# Generacion:  927  Mejor aptitud:  27
# Generacion:  928  Mejor aptitud:  27
# Generacion:  929  Mejor aptitud:  27
# Generacion:  930  Mejor aptitud:  27
# Generacion:  931  Mejor aptitud:  25
# Generacion:  932  Mejor aptitud:  25
# Generacion:  933  Mejor aptitud:  25
# Generacion:  934  Mejor aptitud:  25
# Generacion:  935  Mejor aptitud:  25
# Generacion:  936  Mejor aptitud:  25
# Generacion:  937  Mejor aptitud:  25
# Generacion:  938  Mejor aptitud:  25
# Generacion:  939  Mejor aptitud:  25
# Generacion:  940  Mejor aptitud:  25
# Generacion:  941  Mejor aptitud:  25
# Generacion:  942  Mejor aptitud:  25
# Generacion:  943  Mejor aptitud:  25
# Generacion:  944  Mejor aptitud:  25
# Generacion:  945  Mejor aptitud:  24
# Generacion:  946  Mejor aptitud:  24
# Generacion:  947  Mejor aptitud:  24
# Generacion:  948  Mejor aptitud:  24
# Generacion:  949  Mejor aptitud:  24
# Generacion:  950  Mejor aptitud:  24
# Generacion:  951  Mejor aptitud:  24
# Generacion:  952  Mejor aptitud:  24
# Generacion:  953  Mejor aptitud:  24
# Generacion:  954  Mejor aptitud:  24
# Generacion:  955  Mejor aptitud:  24
# Generacion:  956  Mejor aptitud:  24
# Generacion:  957  Mejor aptitud:  24
# Generacion:  958  Mejor aptitud:  24
# Generacion:  959  Mejor aptitud:  24
# Generacion:  960  Mejor aptitud:  24
# Generacion:  961  Mejor aptitud:  24
# Generacion:  962  Mejor aptitud:  24
# Generacion:  963  Mejor aptitud:  24
# Generacion:  964  Mejor aptitud:  24
# Generacion:  965  Mejor aptitud:  24
# Generacion:  966  Mejor aptitud:  24
# Generacion:  967  Mejor aptitud:  24
# Generacion:  968  Mejor aptitud:  24
# Generacion:  969  Mejor aptitud:  24
# Generacion:  970  Mejor aptitud:  24
# Generacion:  971  Mejor aptitud:  25
# Generacion:  972  Mejor aptitud:  25
# Generacion:  973  Mejor aptitud:  25
# Generacion:  974  Mejor aptitud:  25
# Generacion:  975  Mejor aptitud:  25
# Generacion:  976  Mejor aptitud:  25
# Generacion:  977  Mejor aptitud:  25
# Generacion:  978  Mejor aptitud:  25
# Generacion:  979  Mejor aptitud:  25
# Generacion:  980  Mejor aptitud:  25
# Generacion:  981  Mejor aptitud:  25
# Generacion:  982  Mejor aptitud:  25
# Generacion:  983  Mejor aptitud:  25
# Generacion:  984  Mejor aptitud:  25
# Generacion:  985  Mejor aptitud:  25
# Generacion:  986  Mejor aptitud:  25
# Generacion:  987  Mejor aptitud:  25
# Generacion:  988  Mejor aptitud:  25
# Generacion:  989  Mejor aptitud:  25
# Generacion:  990  Mejor aptitud:  25
# Generacion:  991  Mejor aptitud:  25
# Generacion:  992  Mejor aptitud:  25
# Generacion:  993  Mejor aptitud:  25
# Generacion:  994  Mejor aptitud:  25
# Generacion:  995  Mejor aptitud:  25
# Generacion:  996  Mejor aptitud:  25
# Generacion:  997  Mejor aptitud:  25
# Generacion:  998  Mejor aptitud:  25
# Generacion:  999  Mejor aptitud:  25
# Generacion:  1000  Mejor aptitud:  25
# Generacion:  1001  Mejor aptitud:  25
# Generacion:  1002  Mejor aptitud:  25
# Generacion:  1003  Mejor aptitud:  24
# Generacion:  1004  Mejor aptitud:  24
# Generacion:  1005  Mejor aptitud:  24
# Generacion:  1006  Mejor aptitud:  24
# Generacion:  1007  Mejor aptitud:  24
# Generacion:  1008  Mejor aptitud:  24
# Generacion:  1009  Mejor aptitud:  24
# Generacion:  1010  Mejor aptitud:  24
# Generacion:  1011  Mejor aptitud:  24
# Generacion:  1012  Mejor aptitud:  24
# Generacion:  1013  Mejor aptitud:  22
# Generacion:  1014  Mejor aptitud:  22
# Generacion:  1015  Mejor aptitud:  25
# Generacion:  1016  Mejor aptitud:  25
# Generacion:  1017  Mejor aptitud:  25
# Generacion:  1018  Mejor aptitud:  25
# Generacion:  1019  Mejor aptitud:  25
# Generacion:  1020  Mejor aptitud:  25
# Generacion:  1021  Mejor aptitud:  25
# Generacion:  1022  Mejor aptitud:  25
# Generacion:  1023  Mejor aptitud:  25
# Generacion:  1024  Mejor aptitud:  25
# Generacion:  1025  Mejor aptitud:  25
# Generacion:  1026  Mejor aptitud:  25
# Generacion:  1027  Mejor aptitud:  25
# Generacion:  1028  Mejor aptitud:  25
# Generacion:  1029  Mejor aptitud:  25
# Generacion:  1030  Mejor aptitud:  25
# Generacion:  1031  Mejor aptitud:  25
# Generacion:  1032  Mejor aptitud:  25
# Generacion:  1033  Mejor aptitud:  25
# Generacion:  1034  Mejor aptitud:  25
# Generacion:  1035  Mejor aptitud:  25
# Generacion:  1036  Mejor aptitud:  24
# Generacion:  1037  Mejor aptitud:  24
# Generacion:  1038  Mejor aptitud:  24
# Generacion:  1039  Mejor aptitud:  25
# Generacion:  1040  Mejor aptitud:  32
# Generacion:  1041  Mejor aptitud:  32
# Generacion:  1042  Mejor aptitud:  26
# Generacion:  1043  Mejor aptitud:  26
# Generacion:  1044  Mejor aptitud:  26
# Generacion:  1045  Mejor aptitud:  26
# Generacion:  1046  Mejor aptitud:  26
# Generacion:  1047  Mejor aptitud:  26
# Generacion:  1048  Mejor aptitud:  26
# Generacion:  1049  Mejor aptitud:  26
# Generacion:  1050  Mejor aptitud:  26
# Generacion:  1051  Mejor aptitud:  26
# Generacion:  1052  Mejor aptitud:  26
# Generacion:  1053  Mejor aptitud:  26
# Generacion:  1054  Mejor aptitud:  26
# Generacion:  1055  Mejor aptitud:  26
# Generacion:  1056  Mejor aptitud:  26
# Generacion:  1057  Mejor aptitud:  26
# Generacion:  1058  Mejor aptitud:  26
# Generacion:  1059  Mejor aptitud:  26
# Generacion:  1060  Mejor aptitud:  26
# Generacion:  1061  Mejor aptitud:  26
# Generacion:  1062  Mejor aptitud:  26
# Generacion:  1063  Mejor aptitud:  26
# Generacion:  1064  Mejor aptitud:  26
# Generacion:  1065  Mejor aptitud:  26
# Generacion:  1066  Mejor aptitud:  26
# Generacion:  1067  Mejor aptitud:  26
# Generacion:  1068  Mejor aptitud:  26
# Generacion:  1069  Mejor aptitud:  26
# Generacion:  1070  Mejor aptitud:  26
# Generacion:  1071  Mejor aptitud:  26
# Generacion:  1072  Mejor aptitud:  26
# Generacion:  1073  Mejor aptitud:  26
# Generacion:  1074  Mejor aptitud:  26
# Generacion:  1075  Mejor aptitud:  26
# Generacion:  1076  Mejor aptitud:  26
# Generacion:  1077  Mejor aptitud:  26
# Generacion:  1078  Mejor aptitud:  26
# Generacion:  1079  Mejor aptitud:  26
# Generacion:  1080  Mejor aptitud:  26
# Generacion:  1081  Mejor aptitud:  26
# Generacion:  1082  Mejor aptitud:  26
# Generacion:  1083  Mejor aptitud:  26
# Generacion:  1084  Mejor aptitud:  26
# Generacion:  1085  Mejor aptitud:  26
# Generacion:  1086  Mejor aptitud:  26
# Generacion:  1087  Mejor aptitud:  29
# Generacion:  1088  Mejor aptitud:  29
# Generacion:  1089  Mejor aptitud:  29
# Generacion:  1090  Mejor aptitud:  29
# Generacion:  1091  Mejor aptitud:  24
# Generacion:  1092  Mejor aptitud:  24
# Generacion:  1093  Mejor aptitud:  24
# Generacion:  1094  Mejor aptitud:  24
# Generacion:  1095  Mejor aptitud:  24
# Generacion:  1096  Mejor aptitud:  24
# Generacion:  1097  Mejor aptitud:  27
# Generacion:  1098  Mejor aptitud:  27
# Generacion:  1099  Mejor aptitud:  27
# Generacion:  1100  Mejor aptitud:  27
# Generacion:  1101  Mejor aptitud:  26
# Generacion:  1102  Mejor aptitud:  26
# Generacion:  1103  Mejor aptitud:  23
# Generacion:  1104  Mejor aptitud:  23
# Generacion:  1105  Mejor aptitud:  23
# Generacion:  1106  Mejor aptitud:  26
# Generacion:  1107  Mejor aptitud:  26
# Generacion:  1108  Mejor aptitud:  27
# Generacion:  1109  Mejor aptitud:  27
# Generacion:  1110  Mejor aptitud:  27
# Generacion:  1111  Mejor aptitud:  27
# Generacion:  1112  Mejor aptitud:  27
# Generacion:  1113  Mejor aptitud:  27
# Generacion:  1114  Mejor aptitud:  27
# Generacion:  1115  Mejor aptitud:  23
# Generacion:  1116  Mejor aptitud:  23
# Generacion:  1117  Mejor aptitud:  23
# Generacion:  1118  Mejor aptitud:  23
# Generacion:  1119  Mejor aptitud:  23
# Generacion:  1120  Mejor aptitud:  23
# Generacion:  1121  Mejor aptitud:  27
# Generacion:  1122  Mejor aptitud:  27
# Generacion:  1123  Mejor aptitud:  26
# Generacion:  1124  Mejor aptitud:  26
# Generacion:  1125  Mejor aptitud:  25
# Generacion:  1126  Mejor aptitud:  24
# Generacion:  1127  Mejor aptitud:  24
# Generacion:  1128  Mejor aptitud:  24
# Generacion:  1129  Mejor aptitud:  24
# Generacion:  1130  Mejor aptitud:  24
# Generacion:  1131  Mejor aptitud:  24
# Generacion:  1132  Mejor aptitud:  25
# Generacion:  1133  Mejor aptitud:  25
# Generacion:  1134  Mejor aptitud:  25
# Generacion:  1135  Mejor aptitud:  26
# Generacion:  1136  Mejor aptitud:  26
# Generacion:  1137  Mejor aptitud:  26
# Generacion:  1138  Mejor aptitud:  25
# Generacion:  1139  Mejor aptitud:  25
# Generacion:  1140  Mejor aptitud:  25
# Generacion:  1141  Mejor aptitud:  25
# Generacion:  1142  Mejor aptitud:  25
# Generacion:  1143  Mejor aptitud:  25
# Generacion:  1144  Mejor aptitud:  25
# Generacion:  1145  Mejor aptitud:  25
# Generacion:  1146  Mejor aptitud:  25
# Generacion:  1147  Mejor aptitud:  25
# Generacion:  1148  Mejor aptitud:  25
# Generacion:  1149  Mejor aptitud:  19
# Generacion:  1150  Mejor aptitud:  19
# Generacion:  1151  Mejor aptitud:  19
# Generacion:  1152  Mejor aptitud:  19
# Generacion:  1153  Mejor aptitud:  19
# Generacion:  1154  Mejor aptitud:  19
# Generacion:  1155  Mejor aptitud:  19
# Generacion:  1156  Mejor aptitud:  19
# Generacion:  1157  Mejor aptitud:  19
# Generacion:  1158  Mejor aptitud:  19
# Generacion:  1159  Mejor aptitud:  19
# Generacion:  1231  Mejor aptitud:  18
# Generacion:  1232  Mejor aptitud:  18
# Generacion:  1233  Mejor aptitud:  18
# Generacion:  1234  Mejor aptitud:  18
# Generacion:  1235  Mejor aptitud:  18
# Generacion:  1236  Mejor aptitud:  18
# Generacion:  1237  Mejor aptitud:  18
# Generacion:  1238  Mejor aptitud:  18
# Generacion:  1239  Mejor aptitud:  18
# Generacion:  1240  Mejor aptitud:  18
# Generacion:  1241  Mejor aptitud:  18
# Generacion:  1242  Mejor aptitud:  18
# Generacion:  1243  Mejor aptitud:  17
# Generacion:  1244  Mejor aptitud:  16
# Generacion:  1245  Mejor aptitud:  16
# Generacion:  1246  Mejor aptitud:  15
# Generacion:  1247  Mejor aptitud:  15
# Generacion:  1248  Mejor aptitud:  15
# Generacion:  1249  Mejor aptitud:  15
# Generacion:  1250  Mejor aptitud:  15
# Generacion:  1251  Mejor aptitud:  15
# Generacion:  1252  Mejor aptitud:  15
# Generacion:  1253  Mejor aptitud:  15
# Generacion:  1254  Mejor aptitud:  15
# Generacion:  1255  Mejor aptitud:  15
# Generacion:  1256  Mejor aptitud:  15
# Generacion:  1257  Mejor aptitud:  15
# Generacion:  1258  Mejor aptitud:  15
# Generacion:  1259  Mejor aptitud:  15
# Generacion:  1260  Mejor aptitud:  15
# Generacion:  1261  Mejor aptitud:  15
# Generacion:  1262  Mejor aptitud:  15
# Generacion:  1263  Mejor aptitud:  15
# Generacion:  1264  Mejor aptitud:  15
# Generacion:  1265  Mejor aptitud:  15
# Generacion:  1266  Mejor aptitud:  15
# Generacion:  1267  Mejor aptitud:  15
# Generacion:  1268  Mejor aptitud:  15
# Generacion:  1269  Mejor aptitud:  15
# Generacion:  1270  Mejor aptitud:  15
# Generacion:  1271  Mejor aptitud:  13
# Generacion:  1272  Mejor aptitud:  13
# Generacion:  1273  Mejor aptitud:  10
# Generacion:  1274  Mejor aptitud:  10
# Generacion:  1275  Mejor aptitud:  10
# Generacion:  1276  Mejor aptitud:  11
# Generacion:  1277  Mejor aptitud:  11
# Generacion:  1278  Mejor aptitud:  11
# Generacion:  1279  Mejor aptitud:  11
# Generacion:  1280  Mejor aptitud:  11
# Generacion:  1281  Mejor aptitud:  11
# Generacion:  1282  Mejor aptitud:  11
# Generacion:  1283  Mejor aptitud:  11
# Generacion:  1284  Mejor aptitud:  11
# Generacion:  1285  Mejor aptitud:  11
# Generacion:  1286  Mejor aptitud:  9
# Generacion:  1287  Mejor aptitud:  9
# Generacion:  1288  Mejor aptitud:  9
# Generacion:  1289  Mejor aptitud:  9
# Generacion:  1290  Mejor aptitud:  9
# Generacion:  1291  Mejor aptitud:  9
# Generacion:  1292  Mejor aptitud:  8
# ...
# Generacion:  2464  Mejor aptitud:  2
# Generacion:  2465  Mejor aptitud:  2
# Generacion:  2466  Mejor aptitud:  2
# Generacion:  2467  Mejor aptitud:  2
# Generacion:  2468  Mejor aptitud:  2
# Generacion:  2469  Mejor aptitud:  2
# Generacion:  2470  Mejor aptitud:  2
# Generacion:  2471  Mejor aptitud:  2
